# %% [markdown]
# <a href="https://colab.research.google.com/github/bagalibhagyashree12-rgb/python-2026/blob/main/assignment1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name = "Ravi"
age = 22
print(name)
print(age)
# Out:
# Ravi
# 22

# %%
a = 10
b = 5
print(a+b)
print(a-b)
print(a*b)
print(a/b)
print(a%b)
# Out:
# 15
# 5
# 50
# 2.0
# 0

# %%
name =input("enter your name: ")
print("hlo", name)
# Out:
# enter your name: swapna
# hlo swapna

# %%
a = int(input("enter number 1: "))
b = int(input("enter number 2: "))
print("sum:",a+b)
# Out:
# enter number 1: 5
# enter number 2: 6
# sum: 11

# %%
num = int(input("enter number:"))
if num % 2 == 0:
  print("even")
else:
    print("odd")
# Out:
# enter number:4
# even

# %%
marks = int(input("enter marks: "))
if marks >= 90:
  print("grade A")
elif marks >= 75:
  print("grade B")
elif marks >= 50:
  print("grade C")
else:
  print("fail")
# Out:
# enter marks: 80
# grade B

# %%
num =int(input("enter number: "))
if num>0:
  if num % 2== 0:
    print("positive and even")
  else:
    print("positive but odd")
else:
  print("not positive")
# Out:
# enter number: 11
# positive but odd

# %%
username = input("enter username:")
password = input("enter password:")
if username == "admin":
  if password == "1234":
    print("login successful")
  else:
   print("worng password")
else:
  print("invalid username")
# Out:
# enter username:kalpana
# enter password:123
# invalid username

# %%
from pathlib import PureWindowsPath
a = int(input("enter a: "))
b = int(input("enter b: "))
c = int(input("enter c: "))
if a > b:
  if a > c:
    print("a is largest")
  else:
    print("c is largest")
else:
  if b < c:
    print("b is largest")
  else:
    print("c is largest")
# Out:
# enter a: 3
# enter b: 5
# enter c: 7
# b is largest

# %%
num = int(input("enter number:"))
if num > 0:
  print("positive number")
# Out:
# enter number:7
# positive number
