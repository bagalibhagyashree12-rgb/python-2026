# %% [markdown]
# <a href="https://colab.research.google.com/github/bagalibhagyashree12-rgb/python-2026/blob/main/assignment2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num = 10
print("the number is: ",num)
# Out:
# the number is:  10

# %%
num = int(input("enter a number: "))
print(num)
# Out:
# enter a number: 18
# 18

# %%
a = int(input("enter first number: "))
b = int(input("enter second number: "))
print("sum= ",a+b)
# Out:
# enter first number: 25
# enter second number: 65
# sum=  90

# %%
a = int(input("enter number1:"))
b = int(input("enter number2: "))
print("result= ",a-b)
# Out:
# enter number1:90
# enter number2: 35
# result=  55

# %%
a = int(input("enter first number: "))
b = int(input("enter second number: "))
print("result= ",a*b)
# Out:
# enter first number: 23
# enter second number: 6
# result=  138

# %%
a = int(input("enter first number: "))
b = int(input("enter second number: "))
print("result= ",a/b)
# Out:
# enter first number: 50
# enter second number: 2
# result=  25.0

# %%
num = int(input("enter a number: "))
if num > 0:
  print("number is greater than 0")
elif num < 0:
  print("number is less than 0")
else:
  print(" number is zero")
# Out:
# enter a number: 0
#  number is zero

# %%
for i in range(1, 5):
 print(i)
# Out:
# 1
# 2
# 3
# 4

# %%
a = int(input("enter first number: "))
b = int(input("enter second number: "))
if a > b:
  print("greater number is: ",a)
else:
  print("greater number is: ",b)
# Out:
# enter first number: 73
# enter second number: 37
# greater number is:  73

# %%
def add (a,b):
  return a + b
a = 10
b = 15
print("sum= ",add(a,b))
# Out:
# sum=  25
